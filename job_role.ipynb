# %%
#import dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from etl_function import *

# %%
# Load in file
file_path = "Resources/listings2019_2021.csv"

# %%
# Read and display the CSV with Pandas

summary_df = pd.read_csv(file_path,encoding='ISO-8859-1')
summary_df.head()
# Out:
#       jobId                                           jobTitle  \
# 0  38098375  Senior Method Development Immunoassay Scientis...
# 1  38259053        Pricing Data Scientist - Lower North Shore
# 2  38267899        Insights Analyst â Online Video Streaming
# 3  38267995                                Credit Risk Analyst
# 4  38269206                                     Data Scientist
#
#                         jobClassification  \
# 0                    Science & Technology
# 1  Information & Communication Technology
# 2  Information & Communication Technology
# 3            Banking & Financial Services
# 4  Information & Communication Technology
#
#                     jobSubClassification                  advertiserName  \
# 0       Biological & Biomedical Sciences          Hobson Prior Australia
# 1                                  Other         Randstad - Technologies
# 2  Database Development & Administration                           Aurec
# ...

# %%
#Selecting wanted columns

job_role_df = summary_df[["jobId","jobTitle"]]
job_role_df
# Out:
#          jobId                                           jobTitle
# 0     38098375  Senior Method Development Immunoassay Scientis...
# 1     38259053        Pricing Data Scientist - Lower North Shore
# 2     38267899        Insights Analyst â Online Video Streaming
# 3     38267995                                Credit Risk Analyst
# 4     38269206                                     Data Scientist
# ...        ...                                                ...
# 2852  52903494                         Business Reporting Analyst
# 2853  52903504                         Business Reporting Analyst
# 2854  52904581                              Senior Data Scientist
# 2855  52904582  Data Scientist - Fast Growth Company - million...
# 2856  52905493                                     Data Scientist
#
# [2857 rows x 2 columns]

# %%
#Adding new col - job role

job_role_df["jobRole"] = ""
job_role_df
# Out:
# C:\Users\Laurent\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#          jobId                                           jobTitle jobRole
# 0     38098375  Senior Method Development Immunoassay Scientis...
# 1     38259053        Pricing Data Scientist - Lower North Shore
# 2     38267899        Insights Analyst â Online Video Streaming
# 3     38267995                                Credit Risk Analyst
# 4     38269206                                     Data Scientist
# ...        ...                                                ...     ...
# ...

# %%
#Make jobTitle, make data all lower case (case sensitive)

# %%
#define a function that classifies Job Title into 3 main groups i.e. Data Engineer, Data Analyst and Data Scientist

# def my_function(input_df):
#     job_role_df = input_df.copy(deep=True)

#     job_role_df['jobTitle']=job_role_df['jobTitle'].str.lower()
#     job_role_df.loc[job_role_df['jobTitle'].str.contains('engineer'), 'jobRole'] = 'Data Engineer'
#     job_role_df.loc[job_role_df['jobTitle'].str.contains('analyst'), 'jobRole'] = 'Data Analyst'
#     job_role_df.loc[job_role_df['jobTitle'].str.contains('scientist'), 'jobRole'] = 'Data Scientist'
#     return job_role_df

# %%
#Calling function


my_function(job_role_df)
# Out:
#          jobId                                           jobTitle  \
# 0     38098375  senior method development immunoassay scientis...
# 1     38259053        pricing data scientist - lower north shore
# 2     38267899        insights analyst â online video streaming
# 3     38267995                                credit risk analyst
# 4     38269206                                     data scientist
# ...        ...                                                ...
# 2852  52903494                         business reporting analyst
# 2853  52903504                         business reporting analyst
# 2854  52904581                              senior data scientist
# 2855  52904582  data scientist - fast growth company - million...
# 2856  52905493                                     data scientist
#
#              jobRole
# 0     Data Scientist
# 1     Data Scientist
# 2       Data Analyst
# 3       Data Analyst
# 4     Data Scientist
# ...              ...
# ...
