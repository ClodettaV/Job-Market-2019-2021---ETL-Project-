# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#load in file
file_path = "Resources/listings2019_2021.csv"

# %% [markdown]
# Reading the file from csv

# %%
summary_df = pd.read_csv(file_path)
summary_df.head()
# Out:
#       jobId                                           jobTitle  \
# 0  38098375  Senior Method Development Immunoassay Scientis...
# 1  38259053        Pricing Data Scientist - Lower North Shore
# 2  38267899          Insights Analyst – Online Video Streaming
# 3  38267995                                Credit Risk Analyst
# 4  38269206                                     Data Scientist
#
#                         jobClassification  \
# 0                    Science & Technology
# 1  Information & Communication Technology
# 2  Information & Communication Technology
# 3            Banking & Financial Services
# 4  Information & Communication Technology
#
#                     jobSubClassification                  advertiserName  \
# 0       Biological & Biomedical Sciences          Hobson Prior Australia
# 1                                  Other         Randstad - Technologies
# 2  Database Development & Administration                           Aurec
# 3                      Compliance & Risk               Huxley Associates
# 4  Database Development & Administration  FinXL IT Professional Services
#
#    advertiserId  companyId companyName  companyRating          listingDate  \
# 0      30969882        NaN         NaN            NaN  2019-01-16 12:17:41
# 1      26537413        NaN         NaN            NaN  2019-02-04 13:02:22
# 2      39407892        NaN         NaN            NaN  2019-02-05 11:33:08
# 3      26057722        NaN         NaN            NaN  2019-02-05 11:39:26
# 4      33086778        NaN         NaN            NaN  2019-02-05 12:54:11
#
#    ... Haskell Lisp Golang Spark Javascript F# Fortran  first_seen  \
# 0  ...       0    0      0     0          0  0       0  2019-03-06
# 1  ...       0    0      0     0          0  0       0  2019-03-06
# 2  ...       0    0      0     0          0  0       0  2019-03-06
# 3  ...       0    0      0     0          0  0       0  2019-03-06
# 4  ...       0    0      0     0          0  0       0  2019-03-06
#
#     last_seen recruiter
# 0  2019-03-11         1
# 1  2019-03-06         1
# 2  2019-03-07         1
# 3  2019-03-07         1
# 4  2019-03-07         0
#
# [5 rows x 52 columns]

# %% [markdown]
# Creating a table for States

# %%
#creating a required table
state_df = summary_df[["jobId","state"]]
state_df
# Out:
#          jobId                         state
# 0     38098375               New South Wales
# 1     38259053  Australian Capital Territory
# 2     38267899               New South Wales
# 3     38267995               New South Wales
# 4     38269206               New South Wales
# ...        ...                           ...
# 2852  52903494               New South Wales
# 2853  52903504                      Victoria
# 2854  52904581               New South Wales
# 2855  52904582               New South Wales
# 2856  52905493               New South Wales
#
# [2857 rows x 2 columns]

# %% [markdown]
# Creating a table for work type by using appropriate columns

# %%
work_type = summary_df[["jobId","jobClassification","jobSubClassification","workType"]]
work_type
# Out:
#          jobId                       jobClassification  \
# 0     38098375                    Science & Technology
# 1     38259053  Information & Communication Technology
# 2     38267899  Information & Communication Technology
# 3     38267995            Banking & Financial Services
# 4     38269206  Information & Communication Technology
# ...        ...                                     ...
# 2852  52903494  Information & Communication Technology
# 2853  52903504  Information & Communication Technology
# 2854  52904581                    Science & Technology
# 2855  52904582                    Science & Technology
# 2856  52905493  Information & Communication Technology
#
#                                 jobSubClassification       workType
# 0                   Biological & Biomedical Sciences      Full Time
# 1                                              Other      Full Time
# 2              Database Development & Administration      Full Time
# 3                                  Compliance & Risk      Full Time
# 4              Database Development & Administration  Contract/Temp
# ...                                              ...            ...
# 2852           Database Development & Administration  Contract/Temp
# 2853           Database Development & Administration  Contract/Temp
# 2854  Mathematics, Statistics & Information Sciences      Full Time
# 2855  Mathematics, Statistics & Information Sciences      Full Time
# 2856           Database Development & Administration      Full Time
#
# [2857 rows x 4 columns]

# %% [markdown]
# Renaming the columns

# %%
work_type = work_type.rename(columns={"jobClassification": "Industry", "jobSubClassification": "Departments"})
work_type
# Out:
#          jobId                                Industry  \
# 0     38098375                    Science & Technology
# 1     38259053  Information & Communication Technology
# 2     38267899  Information & Communication Technology
# 3     38267995            Banking & Financial Services
# 4     38269206  Information & Communication Technology
# ...        ...                                     ...
# 2852  52903494  Information & Communication Technology
# 2853  52903504  Information & Communication Technology
# 2854  52904581                    Science & Technology
# 2855  52904582                    Science & Technology
# 2856  52905493  Information & Communication Technology
#
#                                          Departments       workType
# 0                   Biological & Biomedical Sciences      Full Time
# 1                                              Other      Full Time
# 2              Database Development & Administration      Full Time
# 3                                  Compliance & Risk      Full Time
# 4              Database Development & Administration  Contract/Temp
# ...                                              ...            ...
# 2852           Database Development & Administration  Contract/Temp
# 2853           Database Development & Administration  Contract/Temp
# 2854  Mathematics, Statistics & Information Sciences      Full Time
# 2855  Mathematics, Statistics & Information Sciences      Full Time
# 2856           Database Development & Administration      Full Time
#
# [2857 rows x 4 columns]

# %% [markdown]
# Exporting tables to csv file

# %%
state_df.to_csv("state.csv")

# %%
work_type.to_csv("work_type.csv")

# %%
# Exporting programming languages table as csv file
state_df.to_csv("state.csv")

# %%
# Exporting programming languages table as csv file
state_df.to_csv("state.csv")
